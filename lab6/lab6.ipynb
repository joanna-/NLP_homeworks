# %%
# put absolute path here
DATA_DIR = r"C:\Users\User\Downloads\saos-dump-23.02.2018.tar\saos-dump-23.02.2018\data\json"

# %%
import os
import json

class DataManager:
    JUDGMENT_DATE_KEY = "judgmentDate"
    COURT_TYPE_KEY = "courtType"

    def __init__(self, data_dir):
        self.data_dir = data_dir

    def get_judgment_year(self, json_content):
        return int(json_content[self.JUDGMENT_DATE_KEY][:4])

    def judgments_generator(self, year='all'):
        for filename in os.listdir(self.data_dir):
            if filename.endswith('.json') and filename.startswith('judgments'):
                with open(os.path.join(self.data_dir, filename), 'r', encoding="utf8") as content_file:
                    content = content_file.read()
                    parsed = json.loads(content)
                    for judgment in parsed["items"]:
                        if year != 'all' and year == self.get_judgment_year(judgment) or year == 'all':           
                            try:
                                if(judgment[self.COURT_TYPE_KEY] in ["COMMON", "SUPREME"]):
                                    yield judgment
                            except:
                                print(judgment["caseNumber"])

data_manager = DataManager(DATA_DIR)

# %%
# Actual homework starts here
import re
generator = data_manager.judgments_generator(year=2009)

# %%
import re

judgments_groups_regex = {
    r'A?C.*': ('sprawy cywilne', []),
    r'A?U.*': ('sprawy z zakresu ubezpieczenia społecznego', []),
    r'A?K.*': ('sprawy karne', []),
    r'G.*': ('sprawy gospodarcze', []),
    r'A?P.*': ('sprawy w zakresie prawa pracy', []),
    r'R.*': ('sprawy w zakresie prawa rodzinnego', []),
    r'W.*': ('sprawy o wykroczenia', []),
    r'Am.*': ('sprawy w zakresie prawa konkurencji', []),
}

def assign_to_group(content):
    for judg_regex in judgments_groups_regex.keys():
        if re.match(judg_regex, content['courtCases'][0]['caseNumber'].split()[1]):
            judgments_groups_regex[judg_regex][1].append(content)
            return
    print(content['courtCases'])

# %%
c = 0
while True:
    try: 
        content = generator.__next__()
        c += 1
#         text = remove_linebreaks(remove_html(content["textContent"]))
        assign_to_group(content)
    except StopIteration:
        break
        
for judg_regex in judgments_groups_regex.keys():
    print("%s: %d" % (judgments_groups_regex[judg_regex][0], len(judgments_groups_regex[judg_regex][1])))
print("Total number of judgments: %d" % c)
# Out:
# [{'caseNumber': 'I BP 12/08'}]
# [{'caseNumber': 'III SK 16/08'}]
# [{'caseNumber': 'III SK 17/08'}]
# [{'caseNumber': 'SNO 90/08'}]
# [{'caseNumber': 'SNO 93/08'}]
# [{'caseNumber': 'SNO 94/08'}]
# [{'caseNumber': 'III SK 24/08'}]
# [{'caseNumber': 'III SK 26/08'}]
# [{'caseNumber': 'SNO 85/08'}]
# [{'caseNumber': 'SNO 86/08'}]
# [{'caseNumber': 'SNO 95/08'}]
# [{'caseNumber': 'SNO 96/08'}]
# [{'caseNumber': 'WZ 75/08'}]
# [{'caseNumber': 'III SK 29/08'}]
# [{'caseNumber': 'III SO 11/08'}]
# [{'caseNumber': 'SNO 1/09'}]
# [{'caseNumber': 'SNO 2/09'}]
# [{'caseNumber': 'SNO 97/08'}]
# [{'caseNumber': 'SNO 6/09'}]
# [{'caseNumber': 'SNO 7/09'}]
# [{'caseNumber': 'SNO 8/09'}]
# [{'caseNumber': 'I BU 9/08'}]
# [{'caseNumber': 'SNO 3/09'}]
# [{'caseNumber': 'SNO 4/09'}]
# [{'caseNumber': 'SNO 5/09'}]
# [{'caseNumber': 'SNO 11/09'}]
# [{'caseNumber': 'SNO 9/09'}]
# [{'caseNumber': 'WO 2/09'}]
# [{'caseNumber': 'WZ 15/09'}]
# [{'caseNumber': 'III SK 35/08'}]
# [{'caseNumber': 'III SPP 3/09'}]
# [{'caseNumber': 'SNO 13/09'}]
# [{'caseNumber': 'SNO 14/09'}]
# [{'caseNumber': 'SNO 15/09'}]
# [{'caseNumber': 'SNO 18/09'}]
# [{'caseNumber': 'SNO 23/09'}]
# [{'caseNumber': 'III SK 19/08'}]
# [{'caseNumber': 'III SK 28/08'}]
# [{'caseNumber': 'III SK 30/08'}]
# [{'caseNumber': 'III SK 36/08'}]
# [{'caseNumber': 'SNO 19/09'}]
# [{'caseNumber': 'SNO 20/09'}]
# [{'caseNumber': 'SNO 21/09'}]
# [{'caseNumber': 'WZ 18/09'}]
# [{'caseNumber': 'SNO 22/09'}]
# [{'caseNumber': 'SNO 24/09'}]
# [{'caseNumber': 'SNO 25/09'}]
# [{'caseNumber': 'SNO 26/09'}]
# [{'caseNumber': 'SNO 27/09'}]
# [{'caseNumber': 'SNO 28/09'}]
# [{'caseNumber': 'SNO 29/09'}]
# [{'caseNumber': 'WZ 23/09'}]
# [{'caseNumber': 'SNO 30/09'}]
# [{'caseNumber': 'SNO 32/09'}]
# [{'caseNumber': 'SNO 33/09'}]
# [{'caseNumber': 'III BU 5/08'}]
# [{'caseNumber': 'III SK 39/08'}]
# [{'caseNumber': 'III SK 41/08'}]
# [{'caseNumber': 'I BP 23/08'}]
# [{'caseNumber': 'SNO 37/09'}]
# [{'caseNumber': 'SNO 38/09'}]
# [{'caseNumber': 'SNO 39/09'}]
# [{'caseNumber': 'SNO 40/09'}]
# [{'caseNumber': 'WZ 29/09'}]
# [{'caseNumber': 'WZ 28/09'}]
# [{'caseNumber': 'SNO 34/09'}]
# [{'caseNumber': 'SNO 35/09'}]
# [{'caseNumber': 'SNO 36/09'}]
# [{'caseNumber': 'III SK 42/08'}]
# [{'caseNumber': 'SNO 10/09'}]
# [{'caseNumber': 'SNO 16/09'}]
# [{'caseNumber': 'SNO 31/09'}]
# [{'caseNumber': 'SNO 41/09'}]
# [{'caseNumber': 'II BU 28/08'}]
# [{'caseNumber': 'III SK 10/09'}]
# [{'caseNumber': 'III SPP 14/09'}]
# [{'caseNumber': 'SNO 17/09'}]
# [{'caseNumber': 'I BP 5/09'}]
# [{'caseNumber': 'III SW 17/09'}]
# [{'caseNumber': 'WA 21/09'}]
# [{'caseNumber': 'SNO 42/09'}]
# [{'caseNumber': 'SNO 43/09'}]
# [{'caseNumber': 'SNO 44/09'}]
# [{'caseNumber': 'SNO 45/09'}]
# [{'caseNumber': 'III SK 34/08'}]
# [{'caseNumber': 'III SW 44/09'}]
# [{'caseNumber': 'III SZP 1/09'}]
# [{'caseNumber': 'I BP 6/09'}]
# [{'caseNumber': 'WSP 1/09'}]
# [{'caseNumber': 'SNO 46/09'}]
# [{'caseNumber': 'SNO 47/09'}]
# [{'caseNumber': 'SNO 48/09'}]
# [{'caseNumber': 'SNO 53/09'}]
# [{'caseNumber': 'SNO 49/09'}]
# [{'caseNumber': 'SNO 50/09'}]
# [{'caseNumber': 'WSP 4/09'}]
# [{'caseNumber': 'WZP 2/09'}]
# [{'caseNumber': 'III SK 4/09'}]
# [{'caseNumber': 'III SK 5/09'}]
# [{'caseNumber': 'III ZS 1/09'}]
# [{'caseNumber': 'III ZS 2/09'}]
# [{'caseNumber': 'III SW 48/09'}]
# [{'caseNumber': 'KSP 13/09'}]
# [{'caseNumber': 'III SK 9/09'}]
# [{'caseNumber': 'SNO 58/09'}]
# [{'caseNumber': 'SNO 62/09'}]
# [{'caseNumber': 'SNO 63/09'}]
# [{'caseNumber': 'SNO 64/09'}]
# [{'caseNumber': 'III SW 47/09'}]
# [{'caseNumber': 'SNO 59/09'}]
# [{'caseNumber': 'SNO 60/09'}]
# [{'caseNumber': 'SNO 61/09'}]
# [{'caseNumber': 'SNO 51/09'}]
# [{'caseNumber': 'SNO 72/09'}]
# [{'caseNumber': 'SNO 73/09'}]
# [{'caseNumber': 'SNO 74/09'}]
# [{'caseNumber': 'SNO 52/09'}]
# [{'caseNumber': 'SNO 54/09'}]
# [{'caseNumber': 'SNO 55/09'}]
# [{'caseNumber': 'SNO 56/09'}]
# [{'caseNumber': 'SNO 57/09'}]
# [{'caseNumber': 'SNO 68/09'}]
# [{'caseNumber': 'SNO 69/09'}]
# [{'caseNumber': 'SNO 70/09'}]
# [{'caseNumber': 'SNO 80/09'}]
# [{'caseNumber': 'SNO 65/09'}]
# [{'caseNumber': 'SNO 66/09'}]
# [{'caseNumber': 'SNO 67/09'}]
# [{'caseNumber': 'SNO 75/09'}]
# [{'caseNumber': 'SNO 76/09'}]
# [{'caseNumber': 'SNO 77/09'}]
# [{'caseNumber': 'WD 7/09'}]
# [{'caseNumber': 'SND 1/09'}]
# [{'caseNumber': 'SNO 78/09'}]
# [{'caseNumber': 'SNO 79/09'}]
# [{'caseNumber': 'SNO 81/09'}]
# [{'caseNumber': 'SNO 86/09'}]
# [{'caseNumber': 'III SZP 2/09'}]
# [{'caseNumber': 'III ZS 3/09'}]
# [{'caseNumber': 'WZ 47/09'}]
# [{'caseNumber': 'I BP 11/09'}]
# [{'caseNumber': 'I BU 10/09'}]
# [{'caseNumber': 'SNO 71/09'}]
# [{'caseNumber': 'SNO 85/09'}]
# [{'caseNumber': 'SNO 87/09'}]
# [{'caseNumber': 'SNO 88/09'}]
# [{'caseNumber': 'II BP 12/09'}]
# [{'caseNumber': 'SNO 82/09'}]
# [{'caseNumber': 'SNO 83/09'}]
# [{'caseNumber': 'WSP 9/09'}]
# [{'caseNumber': 'III SK 20/09'}]
# [{'caseNumber': 'III SK 30/09'}]
# [{'caseNumber': 'I BU 6/09'}]
# [{'caseNumber': 'III SO 2/09'}]
# [{'caseNumber': 'III SK 34/09'}]
# [{'caseNumber': 'III SK 36/09'}]
# [{'caseNumber': 'SNO 89/09'}]
# [{'caseNumber': 'SNO 90/09'}]
# [{'caseNumber': 'SNO 91/09'}]
# [{'caseNumber': 'SNO 94/09'}]
# [{'caseNumber': 'SNO 96/09'}]
# sprawy cywilne: 1489
# sprawy z zakresu ubezpieczenia społecznego: 209
# sprawy karne: 171
# sprawy gospodarcze: 14
# sprawy w zakresie prawa pracy: 259
# sprawy w zakresie prawa rodzinnego: 0
# sprawy o wykroczenia: 0
# sprawy w zakresie prawa konkurencji: 25
# Total number of judgments: 2328
