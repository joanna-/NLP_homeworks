# %%
# put absolute path here
DATA_DIR = r"C:\Users\User\Downloads\saos-dump-23.02.2018.tar\saos-dump-23.02.2018\data\json"

# %%
import os
import json

class DataManager:
    JUDGMENT_DATE_KEY = "judgmentDate"
    COURT_TYPE_KEY = "courtType"

    def __init__(self, data_dir):
        self.data_dir = data_dir

    def get_judgment_year(self, json_content):
        return int(json_content[self.JUDGMENT_DATE_KEY][:4])

    def judgments_generator(self, year='all'):
        for filename in os.listdir(self.data_dir):
            if filename.endswith('.json') and filename.startswith('judgments'):
                with open(os.path.join(self.data_dir, filename), 'r', encoding="utf8") as content_file:
                    content = content_file.read()
                    parsed = json.loads(content)
                    for judgment in parsed["items"]:
                        if year != 'all' and year == self.get_judgment_year(judgment) or year == 'all':           
                            try:
                                if(judgment[self.COURT_TYPE_KEY] in ["COMMON", "SUPREME"]):
                                    yield judgment
                            except:
                                print("not common or supreme: " + str(judgment["caseNumber"]))

data_manager = DataManager(DATA_DIR)

# %%
# Actual homework starts here
import re
generator = data_manager.judgments_generator(year=2009)

# %%
def contain_digit(x):
    return re.search(r'\d', x) is not None

def is_top_20(word):
    tops = ['na', 'do', 'art', 'nie', 'że', 'przez', 'ust', 'się', 'dnia', 'jest', 'oraz', 'ustawy', 'od', 'sąd', 'nr',
           'postępowania', 'pkt', 'tym', 'za', 'sądu']
    return word in tops

def create_bag_of_words(text):
    return [x.lower() for x in re.findall(r'\b\w\w+\b', text, re.UNICODE) 
                       if not contain_digit(x) and not is_top_20(x)]

def remove_html(x):
    return re.sub("<[^>]*>", "", x)

def remove_linebreaks(x):
    return re.sub("-\n", "", x)

# %%
def extract_justification(content):
    text = remove_linebreaks(remove_html(content["textContent"]))
    justification_string = 'UZASADNIENIE'
    splitted = re.split(justification_string, text, flags=re.IGNORECASE, maxsplit=1)
    if len(splitted) > 1:
        return splitted[1]
    print("No justification: %d" % content['id'])
    return False

# %%
import re

judgments_groups_regex = {
    r'A?C.*': ('sprawy cywilne', []),
    r'A?U.*': ('sprawy z zakresu ubezpieczenia społecznego', []),
    r'A?K.*': ('sprawy karne', []),
    r'G.*': ('sprawy gospodarcze', []),
    r'A?P.*': ('sprawy w zakresie prawa pracy', []),
    r'R.*': ('sprawy w zakresie prawa rodzinnego', []),
    r'W.*': ('sprawy o wykroczenia', []),
    r'Am.*': ('sprawy w zakresie prawa konkurencji', []),
}

def assign_to_group(content):
    for judg_regex in judgments_groups_regex.keys():
        if re.match(judg_regex, content['courtCases'][0]['caseNumber'].split()[1]):
            justification = extract_justification(content)
            if justification:
                judgments_groups_regex[judg_regex][1].append(create_bag_of_words(justification))
            return
    print('No groups ' + str(content['courtCases']))

# %%
c = 0
while True: 
    try: 
        content = generator.__next__()
        assign_to_group(content)
        c += 1
    except StopIteration:
        break

for judg_regex in judgments_groups_regex.keys():
    print("%s: %d" % (judgments_groups_regex[judg_regex][0], len(judgments_groups_regex[judg_regex][1])))
print("Total number of judgments: %d" % c)
# Out:
# No groups [{'caseNumber': 'I BP 12/08'}]
# No justification: 89404
# No justification: 89408
# No justification: 89409
# No justification: 89411
# No justification: 89422
# No justification: 89423
# No justification: 89424
# No justification: 89425
# No justification: 89426
# No groups [{'caseNumber': 'III SK 16/08'}]
# No groups [{'caseNumber': 'III SK 17/08'}]
# No justification: 89431
# No groups [{'caseNumber': 'SNO 90/08'}]
# No groups [{'caseNumber': 'SNO 93/08'}]
# No groups [{'caseNumber': 'SNO 94/08'}]
# No justification: 89436
# No justification: 89440
# No justification: 89441
# No justification: 89452
# No groups [{'caseNumber': 'III SK 24/08'}]
# No groups [{'caseNumber': 'III SK 26/08'}]
# No justification: 89439
# No justification: 20527
# No justification: 89433
# No justification: 89434
# No justification: 89515
# No justification: 89509
# No justification: 89513
# No justification: 89493
# No justification: 89556
# No groups [{'caseNumber': 'SNO 85/08'}]
# No groups [{'caseNumber': 'SNO 86/08'}]
# No groups [{'caseNumber': 'SNO 95/08'}]
# No groups [{'caseNumber': 'SNO 96/08'}]
# No justification: 70632
# No justification: 89540
# No groups [{'caseNumber': 'WZ 75/08'}]
# No justification: 89603
# No justification: 89601
# No justification: 89602
# No justification: 89624
# No justification: 89605
# No justification: 89609
# No justification: 89611
# No justification: 89636
# No justification: 89639
# No justification: 89649
# No justification: 89650
# No groups [{'caseNumber': 'III SK 29/08'}]
# No groups [{'caseNumber': 'III SO 11/08'}]
# No justification: 89653
# No groups [{'caseNumber': 'SNO 1/09'}]
# No groups [{'caseNumber': 'SNO 2/09'}]
# No groups [{'caseNumber': 'SNO 97/08'}]
# No justification: 89675
# No justification: 89677
# No justification: 89678
# No groups [{'caseNumber': 'SNO 6/09'}]
# No groups [{'caseNumber': 'SNO 7/09'}]
# No groups [{'caseNumber': 'SNO 8/09'}]
# No justification: 89691
# No groups [{'caseNumber': 'I BU 9/08'}]
# No justification: 89718
# No justification: 89714
# No justification: 89716
# No groups [{'caseNumber': 'SNO 3/09'}]
# No groups [{'caseNumber': 'SNO 4/09'}]
# No groups [{'caseNumber': 'SNO 5/09'}]
# No justification: 89732
# No justification: 39806
# No justification: 89822
# No justification: 89776
# No justification: 89799
# No justification: 89778
# No justification: 89791
# No justification: 89835
# No justification: 89836
# No justification: 89849
# No justification: 89850
# No justification: 159592
# No justification: 89845
# No justification: 89848
# No groups [{'caseNumber': 'SNO 11/09'}]
# No groups [{'caseNumber': 'SNO 9/09'}]
# No groups [{'caseNumber': 'WO 2/09'}]
# No groups [{'caseNumber': 'WZ 15/09'}]
# No justification: 89853
# No groups [{'caseNumber': 'III SK 35/08'}]
# No groups [{'caseNumber': 'III SPP 3/09'}]
# No justification: 89884
# No justification: 89885
# No justification: 89888
# No justification: 89898
# No justification: 89870
# No justification: 89883
# No justification: 89887
# No justification: 89932
# No justification: 89934
# No justification: 89946
# No groups [{'caseNumber': 'SNO 13/09'}]
# No groups [{'caseNumber': 'SNO 14/09'}]
# No justification: 89959
# No justification: 89929
# No justification: 89930
# No justification: 89937
# No justification: 130471
# No groups [{'caseNumber': 'SNO 15/09'}]
# No groups [{'caseNumber': 'SNO 18/09'}]
# No groups [{'caseNumber': 'SNO 23/09'}]
# No justification: 89975
# No groups [{'caseNumber': 'III SK 19/08'}]
# No groups [{'caseNumber': 'III SK 28/08'}]
# No groups [{'caseNumber': 'III SK 30/08'}]
# No groups [{'caseNumber': 'III SK 36/08'}]
# No justification: 186111
# No justification: 90001
# No justification: 90002
# No justification: 90003
# No justification: 90006
# No groups [{'caseNumber': 'SNO 19/09'}]
# No groups [{'caseNumber': 'SNO 20/09'}]
# No groups [{'caseNumber': 'SNO 21/09'}]
# No justification: 90017
# No justification: 90018
# No justification: 90019
# No justification: 90005
# No justification: 90013
# No justification: 90021
# No groups [{'caseNumber': 'WZ 18/09'}]
# No justification: 90076
# No justification: 90080
# No justification: 90056
# No justification: 90061
# No justification: 90062
# No justification: 189774
# No justification: 90087
# No groups [{'caseNumber': 'SNO 22/09'}]
# No groups [{'caseNumber': 'SNO 24/09'}]
# No groups [{'caseNumber': 'SNO 25/09'}]
# No groups [{'caseNumber': 'SNO 26/09'}]
# No justification: 90090
# No justification: 90092
# No justification: 90119
# No justification: 90120
# No justification: 90121
# No justification: 90146
# No justification: 90132
# No justification: 90133
# No justification: 90134
# No groups [{'caseNumber': 'SNO 27/09'}]
# No groups [{'caseNumber': 'SNO 28/09'}]
# No groups [{'caseNumber': 'SNO 29/09'}]
# No groups [{'caseNumber': 'WZ 23/09'}]
# No justification: 90116
# No groups [{'caseNumber': 'SNO 30/09'}]
# No groups [{'caseNumber': 'SNO 32/09'}]
# No groups [{'caseNumber': 'SNO 33/09'}]
# No justification: 90150
# No justification: 90151
# No justification: 90153
# No justification: 90201
# No justification: 90170
# No justification: 90184
# No groups [{'caseNumber': 'III BU 5/08'}]
# No justification: 90185
# No justification: 90186
# No justification: 90213
# No justification: 90230
# No groups [{'caseNumber': 'III SK 39/08'}]
# No groups [{'caseNumber': 'III SK 41/08'}]
# No groups [{'caseNumber': 'I BP 23/08'}]
# No justification: 90227
# No justification: 90269
# No justification: 90270
# No justification: 90272
# No justification: 41945
# No justification: 90273
# No justification: 90274
# No justification: 90275
# No groups [{'caseNumber': 'SNO 37/09'}]
# No groups [{'caseNumber': 'SNO 38/09'}]
# No groups [{'caseNumber': 'SNO 39/09'}]
# No groups [{'caseNumber': 'SNO 40/09'}]
# No justification: 90307
# No justification: 90312
# No justification: 90313
# No justification: 90311
# No justification: 90314
# No justification: 90315
# No justification: 90360
# No groups [{'caseNumber': 'WZ 29/09'}]
# No justification: 90334
# No groups [{'caseNumber': 'WZ 28/09'}]
# No justification: 90335
# No justification: 90377
# No justification: 90379
# No justification: 90383
# No groups [{'caseNumber': 'SNO 34/09'}]
# No groups [{'caseNumber': 'SNO 35/09'}]
# No groups [{'caseNumber': 'SNO 36/09'}]
# No justification: 90376
# No justification: 90385
# No groups [{'caseNumber': 'III SK 42/08'}]
# No justification: 90401
# No justification: 90429
# No justification: 90430
# No groups [{'caseNumber': 'SNO 10/09'}]
# No justification: 90468
# No justification: 90486
# No justification: 90465
# No justification: 70634
# No justification: 90496
# No justification: 14873
# No groups [{'caseNumber': 'SNO 16/09'}]
# No groups [{'caseNumber': 'SNO 31/09'}]
# No groups [{'caseNumber': 'SNO 41/09'}]
# No justification: 136856
# No justification: 90505
# No justification: 90498
# No groups [{'caseNumber': 'II BU 28/08'}]
# No justification: 90502
# No justification: 90506
# No groups [{'caseNumber': 'III SK 10/09'}]
# No groups [{'caseNumber': 'III SPP 14/09'}]
# No groups [{'caseNumber': 'SNO 17/09'}]
# No justification: 90575
# No groups [{'caseNumber': 'I BP 5/09'}]
# No justification: 90538
# No justification: 90555
# No groups [{'caseNumber': 'III SW 17/09'}]
# No groups [{'caseNumber': 'WA 21/09'}]
# No justification: 237788
# No groups [{'caseNumber': 'SNO 42/09'}]
# No groups [{'caseNumber': 'SNO 43/09'}]
# No groups [{'caseNumber': 'SNO 44/09'}]
# No groups [{'caseNumber': 'SNO 45/09'}]
# No justification: 90607
# No justification: 90608
# No justification: 90610
# No justification: 90611
# No groups [{'caseNumber': 'III SK 34/08'}]
# No groups [{'caseNumber': 'III SW 44/09'}]
# No groups [{'caseNumber': 'III SZP 1/09'}]
# No justification: 13216
# No groups [{'caseNumber': 'I BP 6/09'}]
# No justification: 90593
# No justification: 90662
# No groups [{'caseNumber': 'WSP 1/09'}]
# No justification: 90639
# No groups [{'caseNumber': 'SNO 46/09'}]
# No groups [{'caseNumber': 'SNO 47/09'}]
# No groups [{'caseNumber': 'SNO 48/09'}]
# No groups [{'caseNumber': 'SNO 53/09'}]
# No justification: 90660
# No justification: 90637
# No justification: 90638
# No justification: 90641
# No justification: 90644
# No justification: 90668
# No groups [{'caseNumber': 'SNO 49/09'}]
# No groups [{'caseNumber': 'SNO 50/09'}]
# No justification: 90677
# No justification: 90691
# No justification: 90701
# No justification: 90703
# No justification: 90705
# No justification: 90696
# No justification: 90699
# No justification: 90718
# No justification: 159610
# No justification: 90719
# No justification: 90721
# No groups [{'caseNumber': 'WSP 4/09'}]
# No groups [{'caseNumber': 'WZP 2/09'}]
# No groups [{'caseNumber': 'III SK 4/09'}]
# No groups [{'caseNumber': 'III SK 5/09'}]
# No justification: 90756
# No groups [{'caseNumber': 'III ZS 1/09'}]
# No groups [{'caseNumber': 'III ZS 2/09'}]
# No justification: 90775
# No justification: 90783
# No groups [{'caseNumber': 'III SW 48/09'}]
# No justification: 90778
# No justification: 90779
# No justification: 90780
# No justification: 90799
# No justification: 90801
# No justification: 90802
# No groups [{'caseNumber': 'KSP 13/09'}]
# No justification: 90811
# No groups [{'caseNumber': 'III SK 9/09'}]
# No justification: 90816
# No justification: 90817
# No justification: 90818
# No groups [{'caseNumber': 'SNO 58/09'}]
# No justification: 90850
# No justification: 90851
# No justification: 90873
# No justification: 90858
# No justification: 90859
# No justification: 189530
# No justification: 15749
# No justification: 90870
# No groups [{'caseNumber': 'SNO 62/09'}]
# No groups [{'caseNumber': 'SNO 63/09'}]
# No groups [{'caseNumber': 'SNO 64/09'}]
# No justification: 90903
# No justification: 90904
# No justification: 90909
# No justification: 90913
# No groups [{'caseNumber': 'III SW 47/09'}]
# No groups [{'caseNumber': 'SNO 59/09'}]
# No groups [{'caseNumber': 'SNO 60/09'}]
# No groups [{'caseNumber': 'SNO 61/09'}]
# No groups [{'caseNumber': 'SNO 51/09'}]
# No groups [{'caseNumber': 'SNO 72/09'}]
# No groups [{'caseNumber': 'SNO 73/09'}]
# No groups [{'caseNumber': 'SNO 74/09'}]
# No justification: 90932
# No justification: 90933
# No justification: 90944
# No groups [{'caseNumber': 'SNO 52/09'}]
# No groups [{'caseNumber': 'SNO 54/09'}]
# No groups [{'caseNumber': 'SNO 55/09'}]
# No justification: 90939
# No justification: 90940
# No groups [{'caseNumber': 'SNO 56/09'}]
# No groups [{'caseNumber': 'SNO 57/09'}]
# No justification: 90985
# No justification: 91014
# No justification: 90980
# No justification: 90981
# No justification: 90982
# No groups [{'caseNumber': 'SNO 68/09'}]
# No groups [{'caseNumber': 'SNO 69/09'}]
# No groups [{'caseNumber': 'SNO 70/09'}]
# No groups [{'caseNumber': 'SNO 80/09'}]
# No justification: 91047
# No justification: 91048
# No groups [{'caseNumber': 'SNO 65/09'}]
# No groups [{'caseNumber': 'SNO 66/09'}]
# No groups [{'caseNumber': 'SNO 67/09'}]
# No groups [{'caseNumber': 'SNO 75/09'}]
# No groups [{'caseNumber': 'SNO 76/09'}]
# No groups [{'caseNumber': 'SNO 77/09'}]
# No groups [{'caseNumber': 'WD 7/09'}]
# No justification: 91036
# No justification: 91038
# No justification: 91075
# No groups [{'caseNumber': 'SND 1/09'}]
# No justification: 40925
# No justification: 91079
# No justification: 38142
# No justification: 37588
# No justification: 91125
# No justification: 91126
# No justification: 91128
# No justification: 91108
# No justification: 91111
# No justification: 91112
# No justification: 91115
# No justification: 91116
# No justification: 91121
# No justification: 91129
# No groups [{'caseNumber': 'SNO 78/09'}]
# No groups [{'caseNumber': 'SNO 79/09'}]
# No groups [{'caseNumber': 'SNO 81/09'}]
# No groups [{'caseNumber': 'SNO 86/09'}]
# No justification: 165119
# No justification: 189517
# No justification: 91202
# No justification: 165111
# No justification: 165114
# No justification: 91203
# No justification: 91204
# No groups [{'caseNumber': 'III SZP 2/09'}]
# No groups [{'caseNumber': 'III ZS 3/09'}]
# No justification: 21029
# No justification: 91208
# No justification: 91209
# No groups [{'caseNumber': 'WZ 47/09'}]
# No justification: 159604
# No groups [{'caseNumber': 'I BP 11/09'}]
# No groups [{'caseNumber': 'I BU 10/09'}]
# No justification: 165120
# No justification: 91245
# No justification: 91270
# No groups [{'caseNumber': 'SNO 71/09'}]
# No justification: 21034
# No justification: 37591
# No justification: 91306
# No justification: 91338
# No groups [{'caseNumber': 'SNO 85/09'}]
# No groups [{'caseNumber': 'SNO 87/09'}]
# No groups [{'caseNumber': 'SNO 88/09'}]
# No groups [{'caseNumber': 'II BP 12/09'}]
# No groups [{'caseNumber': 'SNO 82/09'}]
# No groups [{'caseNumber': 'SNO 83/09'}]
# No justification: 91397
# No justification: 91399
# No justification: 91400
# No groups [{'caseNumber': 'WSP 9/09'}]
# No justification: 91416
# No groups [{'caseNumber': 'III SK 20/09'}]
# No groups [{'caseNumber': 'III SK 30/09'}]
# No justification: 91419
# No groups [{'caseNumber': 'I BU 6/09'}]
# No justification: 91434
# No justification: 91435
# No justification: 91436
# No justification: 91437
# No groups [{'caseNumber': 'III SO 2/09'}]
# No justification: 174024
# No justification: 91440
# No justification: 91442
# No justification: 91431
# No justification: 91432
# No groups [{'caseNumber': 'III SK 34/09'}]
# No groups [{'caseNumber': 'III SK 36/09'}]
# No justification: 91439
# No justification: 91505
# No justification: 91506
# No justification: 131698
# No justification: 91514
# No groups [{'caseNumber': 'SNO 89/09'}]
# No groups [{'caseNumber': 'SNO 90/09'}]
# No groups [{'caseNumber': 'SNO 91/09'}]
# No groups [{'caseNumber': 'SNO 94/09'}]
# No groups [{'caseNumber': 'SNO 96/09'}]
# No justification: 38420
# No justification: 91541
# sprawy cywilne: 1480
# sprawy z zakresu ubezpieczenia społecznego: 124
# sprawy karne: 101
# sprawy gospodarcze: 4
# sprawy w zakresie prawa pracy: 168
# sprawy w zakresie prawa rodzinnego: 0
# sprawy o wykroczenia: 0
# sprawy w zakresie prawa konkurencji: 19
# Total number of judgments: 0

# %%
import random

def split_dataset(data, test_ratio=0.25):   
    random.shuffle(data)
    split_num = int(test_ratio * len(data))
    train_data = data[split_num:]
    test_data = data[:split_num]
    return train_data, test_data

# %%
import requests 

def send_post_request(sample):
    text = ' '.join(sample)
    r = requests.post("http://192.168.99.100:9200/", data=text.encode('utf-8') )
    r.encoding = 'utf-8'
    return r.text

def process_post_response(text):
    flexed = []
    base = []
    lines = text.splitlines()
    for index, line in enumerate(lines):
        if ':' in line:
            try:
                splitted = line.split(':', 1)[0].split()
                line_before = lines[index-1]
                base.append(splitted[0].lower())
                flexed.append(line_before.split()[0])
            except:
                print(line)
    return flexed, base

# %%
# %%time

training_x = []
training_y = []
test_x = []
test_y = []
base_training_x= []
base_test_x = []
for key in (r'A?C.*', r'A?U.*', r'A?K.*', r'A?P.*'):
    data = judgments_groups_regex[key][1]
    train_data, test_data = split_dataset(data)
    for sample in train_data:
        flexed, base = process_post_response(send_post_request(sample))
        base_training_x.append(base)
        training_x.append(flexed)
        training_y.append(key)
    for sample in test_data:
        flexed, base = process_post_response(send_post_request(sample))
        base_test_x.append(base)
        test_x.append(flexed)
        test_y.append(key)
# Out:
# Wall time: 2h 10min 56s

# %%
print(len(training_x))
print(len(training_y))
print(len(test_x))
print(len(test_y))
print(len(base_training_x))
print(len(base_test_x))
# Out:
# 1405
# 1405
# 468
# 468
# 1405
# 468

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def prepare_tfidf(training, test):
    vectorizer = TfidfVectorizer()
    training = vectorizer.fit_transform([' '.join(sample) for sample in training])
    test = vectorizer.transform([' '.join(sample) for sample in test])
    return training, test

transformed_training_x, transformed_test_x = prepare_tfidf(training_x, test_x)
transformed_base_training_x, transformed_base_test_x = prepare_tfidf(base_training_x, base_test_x)

print(transformed_training_x.shape)
print(transformed_base_training_x.shape)
print(transformed_test_x.shape)
print(transformed_base_test_x.shape)
# Out:
# (1405, 46198)
# (1405, 14861)
# (468, 46198)
# (468, 14861)

# %%
clf_base = svm.SVC(C=100, kernel='rbf', gamma=0.01)
clf_base.fit(transformed_base_training_x, training_y)

clf_flexed = svm.SVC(C=100, kernel='rbf', gamma=0.01)
clf_flexed.fit(transformed_training_x, training_y)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support, confusion_matrix
def make_predition(clf, test_x, test_y, text=""):
    prediction_result = clf.predict(test_x)
#     print(prediction_result)
    print(text)
    print("accuracy " + str(accuracy_score(test_y, prediction_result)))
    print("confusion matrix: \n" + str(confusion_matrix(test_y, prediction_result)))
    print(str(classification_report(test_y, prediction_result, 
                                    target_names=[judgments_groups_regex[key][0] for key in clf.classes_])))
    print("micro-average: " + str(precision_recall_fscore_support(test_y, prediction_result, average='micro')[:-1]))
    print("macro-average: " + str(precision_recall_fscore_support(test_y, prediction_result, average='macro')[:-1]))
    
make_predition(clf_base, transformed_base_test_x, test_y, text="BASE")
make_predition(clf_flexed, transformed_test_x, test_y, text="\nFLEXED")
# Out:
# BASE
# accuracy 0.961538461538
# confusion matrix:
# [[368   0   2   0]
#  [  0  25   0   0]
#  [  9   1  32   0]
#  [  3   0   3  25]]
#                                             precision    recall  f1-score   support
#
#                             sprawy cywilne       0.97      0.99      0.98       370
#                               sprawy karne       0.96      1.00      0.98        25
#              sprawy w zakresie prawa pracy       0.86      0.76      0.81        42
# sprawy z zakresu ubezpieczenia społecznego       1.00      0.81      0.89        31
#
#                                avg / total       0.96      0.96      0.96       468
#
# micro-average: (0.96153846153846156, 0.96153846153846156, 0.96153846153846156)
# macro-average: (0.94870609475872636, 0.89073774235064551, 0.9161773038329255)
#
# FLEXED
# accuracy 0.963675213675
# confusion matrix:
# [[368   0   2   0]
#  [  0  25   0   0]
#  [ 10   0  32   0]
#  [  4   0   1  26]]
#                                             precision    recall  f1-score   support
#
#                             sprawy cywilne       0.96      0.99      0.98       370
#                               sprawy karne       1.00      1.00      1.00        25
#              sprawy w zakresie prawa pracy       0.91      0.76      0.83        42
# sprawy z zakresu ubezpieczenia społecznego       1.00      0.84      0.91        31
#
#                                avg / total       0.96      0.96      0.96       468
#
# micro-average: (0.96367521367521369, 0.96367521367521369, 0.96367521367521369)
# macro-average: (0.9694091249065071, 0.89880225847967787, 0.93054323429463404)
