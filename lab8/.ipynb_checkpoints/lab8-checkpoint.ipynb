# %%
import requests
import time

url = 'http://ws.clarin-pl.eu/nlprest2/base'

def process(text):
    file_id = requests.post(url + '/upload/', data=text.encode('utf-8'), headers={'Content-Type': 'binary/octet-stream'}).text
    task_id = requests.post(url + '/startTask/', 
                            json={'lpmn': 'any2txt|wcrft2|liner2({"model":"n82"})', 'file': file_id, 'user': ''},
                            headers={'Content-Type': 'application/json'}).text
    print(task_id)
    response = requests.get(url + '/getStatus/' + task_id).json()
    print(response)
    while response["status"] == "QUEUE" or response["status"] == "PROCESSING" :
        time.sleep(0.5)
        response = requests.get(url + '/getStatus/' + task_id).json()
        
    if response["status"]=="ERROR":
            print("Error " + data["value"]);
            return None
    
    if response['status'] == 'DONE' and response['value']:
        return requests.get(url + '/download' + response['value'][0]['fileID']).text

# %%
# put absolute path here
DATA_DIR = r"C:\Users\Joanna\NLP_homeworks\json"

# %%
# making usage of my helper .py file in jupyter environment on any computer# makin 
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from file_utils import *
data_manager = DataManager(DATA_DIR)

# %%
# Actual homework starts here# Actua 
import re
generator = data_manager.judgments_generator(year=2009)

# %%
def remove_html(x):
    return re.sub("<[^>]*>", "", x)

def remove_linebreaks(x):
    return re.sub("-\n", "", x)

# %%
counter = 0
while counter < 1:
    try:
        content = generator.__next__()
        text = remove_linebreaks(remove_html(content["textContent"]))
        processed = process(text)
        print(processed)
        if processed:
            counter += 1
    except StopIteration:
        break
# Out:
# 5737942f-b277-4efc-b543-c197e1084a73
# {'value': 0, 'status': 'NOTEXISTING'}
# None
# cabfc213-f284-4c5b-bd61-ca35a7f120b8
# {'value': 0, 'status': 'NOTEXISTING'}
# None
# 1c8a4272-8866-4d51-b3d2-15f6936eaaa5
# {'value': 0, 'status': 'NOTEXISTING'}
# None
# ff342f3c-50b7-4b92-9cb9-b70d4bb0859f
# {'value': 0, 'status': 'NOTEXISTING'}
# None
# 4d10d5f2-554f-42ed-a22d-3b959013d0b7
# {'value': 0, 'status': 'QUEUE'}
# <?xml version="1.0" encoding="UTF-8"?>
# <!DOCTYPE chunkList SYSTEM "ccl.dtd">
# <chunkList>
#  <chunk type="p" id="ch1">
#   <sentence id="s1">
#    <tok>
#     <orth>Wyrok</orth>
#     <lex disamb="1"><base>wyrok</base><ctag>subst:sg:nom:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>dnia</orth>
#     <lex disamb="1"><base>dzień</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>6</orth>
#     <lex disamb="1"><base>6</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>stycznia</orth>
#     <lex disamb="1"><base>styczeń</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>2009</orth>
#     <lex disamb="1"><base>2009</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>r</orth>
#     <lex disamb="1"><base>r</base><ctag>ign</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch2">
#   <sentence id="s2">
#    <tok>
#     <orth>I</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>PK</orth>
#     <lex disamb="1"><base>PK</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>117</orth>
#     <lex disamb="1"><base>117</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>/</orth>
#     <lex disamb="1"><base>/</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>08</orth>
#     <lex disamb="1"><base>08</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>Na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>podstawie</orth>
#     <lex disamb="1"><base>podstawa</base><ctag>subst:sg:dat:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>art</orth>
#     <lex disamb="1"><base>art</base><ctag>ign</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>390</orth>
#     <lex disamb="1"><base>390</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>§</orth>
#     <lex disamb="1"><base>§</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>1</orth>
#     <lex disamb="1"><base>1</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>k</orth>
#     <lex disamb="1"><base>k</base><ctag>prep:dat</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>c</orth>
#     <lex disamb="1"><base>cent</base><ctag>brev:npun</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>związku</orth>
#     <lex disamb="1"><base>związek</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>art</orth>
#     <lex disamb="1"><base>art</base><ctag>ign</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>300</orth>
#     <lex disamb="1"><base>300</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>k</orth>
#     <lex disamb="1"><base>k</base><ctag>prep:dat</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>p</orth>
#     <lex disamb="1"><base>p</base><ctag>ign</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>jeżeli</orth>
#     <lex disamb="1"><base>jeżeli</base><ctag>comp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>strona</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zobowiązana</orth>
#     <lex disamb="1"><base>zobowiązana</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>do</orth>
#     <lex disamb="1"><base>do</base><ctag>prep:gen</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zawarcia</orth>
#     <lex disamb="1"><base>zawarcie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przyrzeczonej</orth>
#     <lex disamb="1"><base>przyrzec</base><ctag>ppas:sg:gen:f:perf:aff</ctag></lex>
#    </tok>
#    <tok>
#     <orth>umowy</orth>
#     <lex disamb="1"><base>umowa</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>o</orth>
#     <lex disamb="1"><base>o</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>pracę</orth>
#     <lex disamb="1"><base>praca</base><ctag>subst:sg:acc:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>(</orth>
#     <lex disamb="1"><base>(</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>pracodawca</orth>
#     <lex disamb="1"><base>pracodawca</base><ctag>subst:sg:nom:m1</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>)</orth>
#     <lex disamb="1"><base>)</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>uchyla</orth>
#     <lex disamb="1"><base>uchylać</base><ctag>fin:sg:ter:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>się</orth>
#     <lex disamb="1"><base>się</base><ctag>qub</ctag></lex>
#    </tok>
#    <tok>
#     <orth>od</orth>
#     <lex disamb="1"><base>od</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>jej</orth>
#     <lex disamb="1"><base>on</base><ctag>ppron3:sg:gen:f:ter:akc:npraep</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zawarcia</orth>
#     <lex disamb="1"><base>zawarcie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>druga</orth>
#     <lex disamb="1"><base>druga</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>strona</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>(</orth>
#     <lex disamb="1"><base>(</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>pracownik</orth>
#     <lex disamb="1"><base>pracownik</base><ctag>subst:sg:nom:m1</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>)</orth>
#     <lex disamb="1"><base>)</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>może</orth>
#     <lex disamb="1"><base>może</base><ctag>qub</ctag></lex>
#    </tok>
#    <tok>
#     <orth>żądać</orth>
#     <lex disamb="1"><base>żądać</base><ctag>inf:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>naprawienia</orth>
#     <lex disamb="1"><base>naprawienie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>szkody</orth>
#     <lex disamb="1"><base>szkoda</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>polegającej</orth>
#     <lex disamb="1"><base>polegać</base><ctag>pact:sg:gen:f:imperf:aff</ctag></lex>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>utracie</orth>
#     <lex disamb="1"><base>utrata</base><ctag>subst:sg:dat:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>wynagrodzenia</orth>
#     <lex disamb="1"><base>wynagrodzenie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>uzyskiwanego</orth>
#     <lex disamb="1"><base>uzyskiwać</base><ctag>ppas:sg:gen:m1:imperf:aff</ctag></lex>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>stosunku</orth>
#     <lex disamb="1"><base>stosunek</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>pracy</orth>
#     <lex disamb="1"><base>praca</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>który</orth>
#     <lex disamb="1"><base>który</base><ctag>adj:sg:nom:m1:pos</ctag></lex>
#    </tok>
#    <tok>
#     <orth>został</orth>
#     <lex disamb="1"><base>zostać</base><ctag>praet:sg:m1:perf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przez</orth>
#     <lex disamb="1"><base>przez</base><ctag>prep:acc:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>nią</orth>
#     <lex disamb="1"><base>on</base><ctag>ppron3:sg:inst:f:ter:akc:npraep</ctag></lex>
#    </tok>
#    <tok>
#     <orth>rozwiązany</orth>
#     <lex disamb="1"><base>rozwiązać</base><ctag>ppas:sg:nom:m1:perf:aff</ctag></lex>
#    </tok>
#    <tok>
#     <orth>dlatego</orth>
#     <lex disamb="1"><base>dlatego</base><ctag>adv:pos</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>że</orth>
#     <lex disamb="1"><base>że</base><ctag>comp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>liczyła</orth>
#     <lex disamb="1"><base>liczyć</base><ctag>praet:sg:f:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zawarcie</orth>
#     <lex disamb="1"><base>zawarcie</base><ctag>subst:sg:nom:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>umowy</orth>
#     <lex disamb="1"><base>umowa</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przyrzeczonej</orth>
#     <lex disamb="1"><base>przyrzec</base><ctag>ppas:sg:gen:f:perf:aff</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>a</orth>
#     <lex disamb="1"><base>a</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>nie</orth>
#     <lex disamb="1"><base>nie</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>szkody</orth>
#     <lex disamb="1"><base>szkoda</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>polegającej</orth>
#     <lex disamb="1"><base>polegać</base><ctag>pact:sg:gen:f:imperf:aff</ctag></lex>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>utracie</orth>
#     <lex disamb="1"><base>utrata</base><ctag>subst:sg:dat:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>wynagrodzenia</orth>
#     <lex disamb="1"><base>wynagrodzenie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>które</orth>
#     <lex disamb="1"><base>który</base><ctag>adj:sg:nom:n:pos</ctag></lex>
#    </tok>
#    <tok>
#     <orth>miała</orth>
#     <lex disamb="1"><base>mieć</base><ctag>praet:sg:f:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>otrzymywać</orth>
#     <lex disamb="1"><base>otrzymywać</base><ctag>inf:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>według</orth>
#     <lex disamb="1"><base>według</base><ctag>prep:gen</ctag></lex>
#    </tok>
#    <tok>
#     <orth>ustaleń</orth>
#     <lex disamb="1"><base>ustalenie</base><ctag>subst:pl:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>umowy</orth>
#     <lex disamb="1"><base>umowa</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przyrzeczonej</orth>
#     <lex disamb="1"><base>przyrzec</base><ctag>ppas:sg:gen:f:perf:aff</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch3">
#   <sentence id="s3">
#    <tok>
#     <orth>Przewodniczący</orth>
#     <lex disamb="1"><base>przewodniczący</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>SSN</orth>
#     <lex disamb="1"><base>SSN</base><ctag>ign</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Józef</orth>
#     <lex disamb="1"><base>Józef</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">1</ann>
#    </tok>
#    <tok>
#     <orth>Iwulski</orth>
#     <lex disamb="1"><base>Iwulski</base><ctag>ign</ctag></lex>
#     <ann chan="nam_liv_person">1</ann>
#    </tok>
#    <tok>
#     <orth>(</orth>
#     <lex disamb="1"><base>(</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>sprawozdawca</orth>
#     <lex disamb="1"><base>sprawozdawca</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>)</orth>
#     <lex disamb="1"><base>)</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Sędziowie</orth>
#     <lex disamb="1"><base>sędzia</base><ctag>subst:pl:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>SN</orth>
#     <lex disamb="1"><base>SN</base><ctag>ign</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>:</orth>
#     <lex disamb="1"><base>:</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Zbigniew</orth>
#     <lex disamb="1"><base>Zbigniew</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">2</ann>
#    </tok>
#    <tok>
#     <orth>Korzeniowski</orth>
#     <lex disamb="1"><base>Korzeniowski</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_liv_person">2</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Jolanta</orth>
#     <lex disamb="1"><base>Jolanta</base><ctag>subst:sg:nom:f</ctag></lex>
#     <ann chan="nam_liv_person">3</ann>
#    </tok>
#    <tok>
#     <orth>Strusińska</orth>
#     <lex disamb="1"><base>Strusińska</base><ctag>ign</ctag></lex>
#     <ann chan="nam_liv_person">3</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">3</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>Żukowska</orth>
#     <lex disamb="1"><base>żukowski</base><ctag>adj:sg:nom:f:pos</ctag></lex>
#     <ann chan="nam_liv_person">3</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch4">
#   <sentence id="s4">
#    <tok>
#     <orth>Sąd</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Najwyższy</orth>
#     <lex disamb="1"><base>najwyższy</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>po</orth>
#     <lex disamb="1"><base>po</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>rozpoznaniu</orth>
#     <lex disamb="1"><base>rozpoznanie</base><ctag>subst:sg:dat:n</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>posiedzeniu</orth>
#     <lex disamb="1"><base>posiedzenie</base><ctag>subst:sg:dat:n</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>niejawnym</orth>
#     <lex disamb="1"><base>niejawny</base><ctag>adj:sg:inst:m1:pos</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>dniu</orth>
#     <lex disamb="1"><base>dzień</base><ctag>subst:sg:loc:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>6</orth>
#     <lex disamb="1"><base>6</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>stycznia</orth>
#     <lex disamb="1"><base>styczeń</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>2009</orth>
#     <lex disamb="1"><base>2009</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>r</orth>
#     <lex disamb="1"><base>r</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>sprawy</orth>
#     <lex disamb="1"><base>sprawa</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>powództwa</orth>
#     <lex disamb="1"><base>powództwo</base><ctag>subst:sg:gen:n</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>Marcina</orth>
#     <lex disamb="1"><base>Marcin</base><ctag>subst:sg:gen:m1</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">1</ann>
#    </tok>
#    <tok>
#     <orth>J</orth>
#     <lex disamb="1"><base>J</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">1</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">1</ann>
#    </tok>
#    <tok>
#     <orth>przeciwko</orth>
#     <lex disamb="1"><base>przeciwko</base><ctag>prep:dat</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <tok>
#     <orth>T</orth>
#     <lex disamb="1"><base>T</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>F</orth>
#     <lex disamb="1"><base>F</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_liv_person">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch5">
#   <sentence id="s5">
#    <tok>
#     <orth>Kable</orth>
#     <lex disamb="1"><base>kabel</base><ctag>subst:pl:nom:m1</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>Spółce</orth>
#     <lex disamb="1"><base>spółka</base><ctag>subst:sg:dat:f</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>o</orth>
#     <lex disamb="1"><base>o</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>o</orth>
#     <lex disamb="1"><base>o</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>Spółce</orth>
#     <lex disamb="1"><base>spółka</base><ctag>subst:sg:dat:f</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>Komandytowo</orth>
#     <lex disamb="1"><base>Komandytowo</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>Akcyjnej</orth>
#     <lex disamb="1"><base>akcyjny</base><ctag>adj:sg:gen:f:pos</ctag></lex>
#     <ann chan="nam_org_company">1</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>K</orth>
#     <lex disamb="1"><base>k</base><ctag>prep:dat</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>o</orth>
#     <lex disamb="1"><base>o</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>zapłatę</orth>
#     <lex disamb="1"><base>zapłata</base><ctag>subst:sg:acc:f</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>odszkodowania</orth>
#     <lex disamb="1"><base>odszkodowanie</base><ctag>subst:sg:gen:n</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>skutek</orth>
#     <lex disamb="1"><base>skutek</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>skargi</orth>
#     <lex disamb="1"><base>skarga</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>kasacyjnej</orth>
#     <lex disamb="1"><base>kasacyjny</base><ctag>adj:sg:gen:f:pos</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>strony</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>pozwanej</orth>
#     <lex disamb="1"><base>pozwana</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>od</orth>
#     <lex disamb="1"><base>od</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>wyroku</orth>
#     <lex disamb="1"><base>wyrok</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>Sądu</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">1</ann>
#    </tok>
#    <tok>
#     <orth>Apelacyjnego</orth>
#     <lex disamb="1"><base>apelacyjny</base><ctag>adj:sg:gen:m1:pos</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">1</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">1</ann>
#    </tok>
#    <tok>
#     <orth>Krakowie</orth>
#     <lex disamb="1"><base>Krak</base><ctag>subst:pl:nom:m1</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">1</ann>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>dnia</orth>
#     <lex disamb="1"><base>dzień</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>17</orth>
#     <lex disamb="1"><base>17</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>grudnia</orth>
#     <lex disamb="1"><base>grudzień</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>2007</orth>
#     <lex disamb="1"><base>2007</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>r</orth>
#     <lex disamb="1"><base>r</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_company">0</ann>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch6">
#   <sentence id="s6">
#    <tok>
#     <orth>[</orth>
#     <lex disamb="1"><base>[</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>]</orth>
#     <lex disamb="1"><base>]</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch7">
#   <sentence id="s7">
#    <tok>
#     <orth>1</orth>
#     <lex disamb="1"><base>1</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>u</orth>
#     <lex disamb="1"><base>u</base><ctag>prep:gen</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>c</orth>
#     <lex disamb="1"><base>cent</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>h</orth>
#     <lex disamb="1"><base>h</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>y</orth>
#     <lex disamb="1"><base>y</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>l</orth>
#     <lex disamb="1"><base>litr</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>ł</orth>
#     <lex disamb="1"><base>ł</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>zaskarżony</orth>
#     <lex disamb="1"><base>zaskarżyć</base><ctag>ppas:sg:nom:m1:perf:aff</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>wyrok</orth>
#     <lex disamb="1"><base>wyrok</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>punkcie</orth>
#     <lex disamb="1"><base>punkt</base><ctag>subst:sg:loc:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>I</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>zmienił</orth>
#     <lex disamb="1"><base>zmienić</base><ctag>praet:sg:m1:perf</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>wyrok</orth>
#     <lex disamb="1"><base>wyrok</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Sądu</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Okręgowego</orth>
#     <lex disamb="1"><base>okręgowy</base><ctag>adj:sg:gen:m1:pos</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>Sądu</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Pracy</orth>
#     <lex disamb="1"><base>praca</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Ubezpieczeń</orth>
#     <lex disamb="1"><base>ubezpieczenie</base><ctag>subst:pl:gen:n</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Społecznych</orth>
#     <lex disamb="1"><base>społeczny</base><ctag>adj:pl:gen:m1:pos</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>Krakowie</orth>
#     <lex disamb="1"><base>Krak</base><ctag>subst:pl:nom:m1</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">1</ann>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>dnia</orth>
#     <lex disamb="1"><base>dzień</base><ctag>subst:sg:gen:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>29</orth>
#     <lex disamb="1"><base>29</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>czerwca</orth>
#     <lex disamb="1"><base>czerwiec</base><ctag>subst:sg:gen:m2</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>2007</orth>
#     <lex disamb="1"><base>2007</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <tok>
#     <orth>r</orth>
#     <lex disamb="1"><base>r</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch8">
#   <sentence id="s8">
#    <tok>
#     <orth>[</orth>
#     <lex disamb="1"><base>[</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>]</orth>
#     <lex disamb="1"><base>]</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>punktach</orth>
#     <lex disamb="1"><base>punkt</base><ctag>subst:pl:loc:m3</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>I</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>III</orth>
#     <lex disamb="1"><base>III</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>ten</orth>
#     <lex disamb="1"><base>ten</base><ctag>adj:sg:nom:m1:pos</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>sposób</orth>
#     <lex disamb="1"><base>sposób</base><ctag>pred</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>że</orth>
#     <lex disamb="1"><base>że</base><ctag>comp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>zasądził</orth>
#     <lex disamb="1"><base>zasądzić</base><ctag>praet:sg:m1:perf</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>od</orth>
#     <lex disamb="1"><base>od</base><ctag>prep:gen:nwok</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>strony</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>pozwanej</orth>
#     <lex disamb="1"><base>pozwana</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>rzecz</orth>
#     <lex disamb="1"><base>rzecz</base><ctag>subst:sg:nom:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>powoda</orth>
#     <lex disamb="1"><base>powód</base><ctag>subst:sg:gen:m1</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>kwotę</orth>
#     <lex disamb="1"><base>kwota</base><ctag>subst:sg:acc:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>4</orth>
#     <lex disamb="1"><base>4</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>000</orth>
#     <lex disamb="1"><base>000</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>(</orth>
#     <lex disamb="1"><base>(</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>cztery</orth>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <lex disamb="1"><base>cztery</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>tysiące</orth>
#     <lex disamb="1"><base>tysiąc</base><ctag>subst:pl:nom:m2</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>)</orth>
#     <lex disamb="1"><base>)</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>zł</orth>
#     <lex disamb="1"><base>złoty</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_oth_currency">1</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>oddalił</orth>
#     <lex disamb="1"><base>oddalić</base><ctag>praet:sg:m1:perf</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>apelację</orth>
#     <lex disamb="1"><base>apelacja</base><ctag>subst:sg:acc:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>powoda</orth>
#     <lex disamb="1"><base>powód</base><ctag>subst:sg:gen:m1</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>pozostałym</orth>
#     <lex disamb="1"><base>pozostały</base><ctag>adj:sg:inst:m1:pos</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>zakresie</orth>
#     <lex disamb="1"><base>zakres</base><ctag>subst:sg:loc:m3</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>;</orth>
#     <lex disamb="1"><base>;</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>2</orth>
#     <lex disamb="1"><base>2</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>o</orth>
#     <lex disamb="1"><base>o</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>d</orth>
#     <lex disamb="1"><base>D</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>d</orth>
#     <lex disamb="1"><base>D</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>a</orth>
#     <lex disamb="1"><base>a</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>l</orth>
#     <lex disamb="1"><base>litr</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>ł</orth>
#     <lex disamb="1"><base>ł</base><ctag>ign</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>skargę</orth>
#     <lex disamb="1"><base>skarga</base><ctag>subst:sg:acc:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>kasacyjną</orth>
#     <lex disamb="1"><base>kasacyjny</base><ctag>adj:sg:acc:f:pos</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>pozostałej</orth>
#     <lex disamb="1"><base>pozostały</base><ctag>adj:sg:gen:f:pos</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>części</orth>
#     <lex disamb="1"><base>część</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>zniósł</orth>
#     <lex disamb="1"><base>znieść</base><ctag>praet:sg:m1:perf:nagl</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>wzajemnie</orth>
#     <lex disamb="1"><base>wzajemnie</base><ctag>adv:pos</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>między</orth>
#     <lex disamb="1"><base>między</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>stronami</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:pl:inst:f</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>koszty</orth>
#     <lex disamb="1"><base>koszt</base><ctag>subst:pl:nom:m3</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <tok>
#     <orth>postępowania</orth>
#     <lex disamb="1"><base>postępowanie</base><ctag>subst:sg:gen:n</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_oth_currency">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch9">
#   <sentence id="s9">
#    <tok>
#     <orth>U</orth>
#     <lex disamb="1"><base>u</base><ctag>prep:gen</ctag></lex>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>a</orth>
#     <lex disamb="1"><base>a</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>s</orth>
#     <lex disamb="1"><base>sekunda</base><ctag>brev:npun</ctag></lex>
#    </tok>
#    <tok>
#     <orth>a</orth>
#     <lex disamb="1"><base>a</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>d</orth>
#     <lex disamb="1"><base>D</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>n</orth>
#     <lex disamb="1"><base>n</base><ctag>ign</ctag></lex>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>e</orth>
#     <lex disamb="1"><base>e</base><ctag>interj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>n</orth>
#     <lex disamb="1"><base>n</base><ctag>ign</ctag></lex>
#    </tok>
#    <tok>
#     <orth>i</orth>
#     <lex disamb="1"><base>i</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>e</orth>
#     <lex disamb="1"><base>e</base><ctag>interj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>Wyrokiem</orth>
#     <lex disamb="1"><base>wyrok</base><ctag>subst:sg:inst:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>dnia</orth>
#     <lex disamb="1"><base>dzień</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>29</orth>
#     <lex disamb="1"><base>29</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>czerwca</orth>
#     <lex disamb="1"><base>czerwiec</base><ctag>subst:sg:gen:m2</ctag></lex>
#    </tok>
#    <tok>
#     <orth>2007</orth>
#     <lex disamb="1"><base>2007</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#    </tok>
#    <tok>
#     <orth>r</orth>
#     <lex disamb="1"><base>r</base><ctag>ign</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch10">
#   <sentence id="s10">
#    <tok>
#     <orth>[</orth>
#     <lex disamb="1"><base>[</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>]</orth>
#     <lex disamb="1"><base>]</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch11">
#   <sentence id="s11">
#    <tok>
#     <orth>Sąd</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">1</ann>
#     <ann chan="nam_loc_gpe_city">0</ann>
# ...
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>p</orth>
#     <lex disamb="1"><base>p</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>c</orth>
#     <lex disamb="1"><base>cent</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>Sąd</orth>
#     <lex disamb="1"><base>sąd</base><ctag>subst:sg:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">2</ann>
#    </tok>
#    <tok>
#     <orth>Najwyższy</orth>
#     <lex disamb="1"><base>najwyższy</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_org_institution">2</ann>
#    </tok>
#    <tok>
#     <orth>uznał</orth>
#     <lex disamb="1"><base>uznać</base><ctag>praet:sg:m1:perf</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>że</orth>
#     <lex disamb="1"><base>że</base><ctag>comp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>koszty</orth>
#     <lex disamb="1"><base>koszt</base><ctag>subst:pl:nom:m3</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>postępowania</orth>
#     <lex disamb="1"><base>postępowanie</base><ctag>subst:sg:gen:n</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>powinny</orth>
#     <lex disamb="1"><base>powinny</base><ctag>adj:sg:nom:m1:pos</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>być</orth>
#     <lex disamb="1"><base>być</base><ctag>inf:imperf</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>wzajemnie</orth>
#     <lex disamb="1"><base>wzajemnie</base><ctag>adv:pos</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>pomiędzy</orth>
#     <lex disamb="1"><base>pomiędzy</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>stronami</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:pl:inst:f</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>zniesione</orth>
#     <lex disamb="1"><base>znieść</base><ctag>ppas:sg:nom:n:perf:aff</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>na</orth>
#     <lex disamb="1"><base>na</base><ctag>prep:acc</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>podstawie</orth>
#     <lex disamb="1"><base>podstawa</base><ctag>subst:sg:dat:f</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>art</orth>
#     <lex disamb="1"><base>art</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>100</orth>
#     <lex disamb="1"><base>100</base><ctag>num:pl:nom:m1:rec</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>k</orth>
#     <lex disamb="1"><base>k</base><ctag>prep:dat</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>p</orth>
#     <lex disamb="1"><base>p</base><ctag>ign</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>c</orth>
#     <lex disamb="1"><base>cent</base><ctag>brev:npun</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>chociaż</orth>
#     <lex disamb="1"><base>chociaż</base><ctag>comp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>powód</orth>
#     <lex disamb="1"><base>powód</base><ctag>subst:sg:nom:m1</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>wygrał</orth>
#     <lex disamb="1"><base>wygrać</base><ctag>praet:sg:m1:perf</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>sprawę</orth>
#     <lex disamb="1"><base>sprawa</base><ctag>subst:sg:acc:f</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>jedynie</orth>
#     <lex disamb="1"><base>jedynie</base><ctag>qub</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>niewielkiej</orth>
#     <lex disamb="1"><base>niewielki</base><ctag>adj:sg:gen:f:pos</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <tok>
#     <orth>części</orth>
#     <lex disamb="1"><base>część</base><ctag>subst:sg:gen:f</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#     <ann chan="nam_org_institution">0</ann>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch126">
#   <sentence id="s126">
#    <tok>
#     <orth>Strona</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>pozwana</orth>
#     <lex disamb="1"><base>pozwana</base><ctag>subst:sg:nom:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>uchyliła</orth>
#     <lex disamb="1"><base>uchylić</base><ctag>praet:sg:f:perf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>się</orth>
#     <lex disamb="1"><base>się</base><ctag>qub</ctag></lex>
#    </tok>
#    <tok>
#     <orth>bowiem</orth>
#     <lex disamb="1"><base>bowiem</base><ctag>comp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>od</orth>
#     <lex disamb="1"><base>od</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zawarcia</orth>
#     <lex disamb="1"><base>zawarcie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>umowy</orth>
#     <lex disamb="1"><base>umowa</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przyrzeczonej</orth>
#     <lex disamb="1"><base>przyrzec</base><ctag>ppas:sg:gen:f:perf:aff</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>co</orth>
#     <lex disamb="1"><base>co</base><ctag>comp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>doprowadziło</orth>
#     <lex disamb="1"><base>doprowadzić</base><ctag>praet:sg:n:perf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>do</orth>
#     <lex disamb="1"><base>do</base><ctag>prep:gen</ctag></lex>
#    </tok>
#    <tok>
#     <orth>powstania</orth>
#     <lex disamb="1"><base>powstanie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>sporu</orth>
#     <lex disamb="1"><base>spór</base><ctag>subst:sg:gen:m3</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>a</orth>
#     <lex disamb="1"><base>a</base><ctag>conj</ctag></lex>
#    </tok>
#    <tok>
#     <orth>oddalenie</orth>
#     <lex disamb="1"><base>oddalenie</base><ctag>subst:sg:nom:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>powództwa</orth>
#     <lex disamb="1"><base>powództwo</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>w</orth>
#     <lex disamb="1"><base>w</base><ctag>prep:acc:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przeważającej</orth>
#     <lex disamb="1"><base>przeważający</base><ctag>adj:sg:gen:f:pos</ctag></lex>
#    </tok>
#    <tok>
#     <orth>części</orth>
#     <lex disamb="1"><base>część</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>jest</orth>
#     <lex disamb="1"><base>być</base><ctag>fin:sg:ter:imperf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>skutkiem</orth>
#     <lex disamb="1"><base>skutek</base><ctag>subst:sg:inst:m3</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zachowania</orth>
#     <lex disamb="1"><base>zachowanie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>powoda</orth>
#     <lex disamb="1"><base>powód</base><ctag>subst:sg:gen:m1</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>,</orth>
#     <lex disamb="1"><base>,</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>który</orth>
#     <lex disamb="1"><base>który</base><ctag>adj:sg:nom:m1:pos</ctag></lex>
#    </tok>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>z</orth>
#     <lex disamb="1"><base>z</base><ctag>prep:gen:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>korzyścią</orth>
#     <lex disamb="1"><base>korzyść</base><ctag>subst:sg:inst:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>dla</orth>
#     <lex disamb="1"><base>dla</base><ctag>prep:gen</ctag></lex>
#    </tok>
#    <tok>
#     <orth>pozwanej</orth>
#     <lex disamb="1"><base>pozwana</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>-</orth>
#     <lex disamb="1"><base>-</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>przez</orth>
#     <lex disamb="1"><base>przez</base><ctag>prep:acc:nwok</ctag></lex>
#    </tok>
#    <tok>
#     <orth>własne</orth>
#     <lex disamb="1"><base>własne</base><ctag>subst:sg:nom:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>działanie</orth>
#     <lex disamb="1"><base>działanie</base><ctag>subst:sg:nom:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>(</orth>
#     <lex disamb="1"><base>(</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>podjęcie</orth>
#     <lex disamb="1"><base>podjęcie</base><ctag>subst:sg:nom:n</ctag></lex>
#    </tok>
#    <tok>
#     <orth>nowego</orth>
#     <lex disamb="1"><base>nowy</base><ctag>subst:sg:gen:m1</ctag></lex>
#    </tok>
#    <tok>
#     <orth>zatrudnienia</orth>
#     <lex disamb="1"><base>zatrudnienie</base><ctag>subst:sg:gen:n</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>)</orth>
#     <lex disamb="1"><base>)</base><ctag>interp</ctag></lex>
#    </tok>
#    <tok>
#     <orth>spowodował</orth>
#     <lex disamb="1"><base>spowodować</base><ctag>praet:sg:m1:perf</ctag></lex>
#    </tok>
#    <tok>
#     <orth>brak</orth>
#     <lex disamb="1"><base>brak</base><ctag>pred</ctag></lex>
#    </tok>
#    <tok>
#     <orth>szkody</orth>
#     <lex disamb="1"><base>szkoda</base><ctag>subst:sg:gen:f</ctag></lex>
#    </tok>
#    <tok>
#     <orth>po</orth>
#     <lex disamb="1"><base>po</base><ctag>prep:acc</ctag></lex>
#    </tok>
#    <tok>
#     <orth>jego</orth>
#     <lex disamb="1"><base>on</base><ctag>ppron3:sg:gen:m1:ter:akc:npraep</ctag></lex>
#    </tok>
#    <tok>
#     <orth>stronie</orth>
#     <lex disamb="1"><base>strona</base><ctag>subst:sg:dat:f</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>.</orth>
#     <lex disamb="1"><base>.</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
#  <chunk type="p" id="ch127">
#   <sentence id="s127">
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#    <ns/>
#    <tok>
#     <orth>=</orth>
#     <lex disamb="1"><base>=</base><ctag>interp</ctag></lex>
#    </tok>
#   </sentence>
#  </chunk>
# </chunkList>
